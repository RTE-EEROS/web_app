# %%
from lca_algebraic.params import _param_registry
# %load_ext autoreload
# %autoreload 2

import bw2io
import brightway2 as bw
import lca_algebraic as agb
from lca_algebraic.export import export_lca
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#bw2io.restore_project_directory("brightway2-project-Parameterized_model_OWF_Original-backup.10-May-2023-08-09AM.tar.gz")

# %%
agb.initProject("Parameterized_model_OWF_Original")
# Out:
# Biosphere database already present!!! No setup is needed

# %%
MODELS = \
    {"per_mw" : 'complete life cycle assessment model of a fixed or floating wind farm per MW',
    "complete_system" : "complete life cycle assessment model of a fixed or floating wind farm",
    "per_kwh": "Full system per kWh electricity produced"}

# %%
bw.databases
# Out:
# Databases dictionary with 3 object(s):
# 	biosphere3
# 	ecoinvent
# 	lif-owi

# %%
agb.loadParams()
# Out:
# Warning : param 'n_turbines' linked to root project instead of a specific DB
# [ParamRegistry] Param n_turbines was already defined in '<project>' : overriding.
# [ParamRegistry] Param n_turbines was already defined in '<project>' : overriding.
# Variable 'n_turbines' was already defined : overidding it with param.
# Warning : param 'turbine_MW' linked to root project instead of a specific DB
# [ParamRegistry] Param turbine_MW was already defined in '<project>' : overriding.
# [ParamRegistry] Param turbine_MW was already defined in '<project>' : overriding.
# Variable 'turbine_MW' was already defined : overidding it with param.
# Warning : param 'life_time' linked to root project instead of a specific DB
# [ParamRegistry] Param life_time was already defined in '<project>' : overriding.
# [ParamRegistry] Param life_time was already defined in '<project>' : overriding.
# Variable 'life_time' was already defined : overidding it with param.
# Warning : param 'availability' linked to root project instead of a specific DB
# [ParamRegistry] Param availability was already defined in '<project>' : overriding.
# [ParamRegistry] Param availability was already defined in '<project>' : overriding.
# Variable 'availability' was already defined : overidding it with param.
# Warning : param 'load_rate' linked to root project instead of a specific DB
# [ParamRegistry] Param load_rate was already defined in '<project>' : overriding.
# [ParamRegistry] Param load_rate was already defined in '<project>' : overriding.
# Variable 'load_rate' was already defined : overidding it with param.
# Warning : param 'fixed_foundations' linked to root project instead of a specific DB
# [ParamRegistry] Param fixed_foundations was already defined in '<project>' : overriding.
# [ParamRegistry] Param fixed_foundations was already defined in '<project>' : overriding.
# Variable 'fixed_foundations' was already defined : overidding it with param.
# Warning : param 'steel_recycled_share_IN' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_recycled_share_IN was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_recycled_share_IN was already defined in '<project>' : overriding.
# Variable 'steel_recycled_share_IN' was already defined : overidding it with param.
# Warning : param 'steel_recycled_share_OUT' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_recycled_share_OUT was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_recycled_share_OUT was already defined in '<project>' : overriding.
# Variable 'steel_recycled_share_OUT' was already defined : overidding it with param.
# Warning : param 'alu_recycled_share_IN' linked to root project instead of a specific DB
# [ParamRegistry] Param alu_recycled_share_IN was already defined in '<project>' : overriding.
# [ParamRegistry] Param alu_recycled_share_IN was already defined in '<project>' : overriding.
# Variable 'alu_recycled_share_IN' was already defined : overidding it with param.
# Warning : param 'alu_recycled_share_OUT' linked to root project instead of a specific DB
# [ParamRegistry] Param alu_recycled_share_OUT was already defined in '<project>' : overriding.
# [ParamRegistry] Param alu_recycled_share_OUT was already defined in '<project>' : overriding.
# Variable 'alu_recycled_share_OUT' was already defined : overidding it with param.
# Warning : param 'alu_landfill_share' linked to root project instead of a specific DB
# [ParamRegistry] Param alu_landfill_share was already defined in '<project>' : overriding.
# [ParamRegistry] Param alu_landfill_share was already defined in '<project>' : overriding.
# Variable 'alu_landfill_share' was already defined : overidding it with param.
# Warning : param 'alu_incineration_share' linked to root project instead of a specific DB
# [ParamRegistry] Param alu_incineration_share was already defined in '<project>' : overriding.
# [ParamRegistry] Param alu_incineration_share was already defined in '<project>' : overriding.
# Variable 'alu_incineration_share' was already defined : overidding it with param.
# Warning : param 'concrete_recycled_share_IN' linked to root project instead of a specific DB
# [ParamRegistry] Param concrete_recycled_share_IN was already defined in '<project>' : overriding.
# [ParamRegistry] Param concrete_recycled_share_IN was already defined in '<project>' : overriding.
# Variable 'concrete_recycled_share_IN' was already defined : overidding it with param.
# Warning : param 'concrete_recycled_share_OUT' linked to root project instead of a specific DB
# [ParamRegistry] Param concrete_recycled_share_OUT was already defined in '<project>' : overriding.
# [ParamRegistry] Param concrete_recycled_share_OUT was already defined in '<project>' : overriding.
# Variable 'concrete_recycled_share_OUT' was already defined : overidding it with param.
# Warning : param 'copper_recycled_share_IN' linked to root project instead of a specific DB
# [ParamRegistry] Param copper_recycled_share_IN was already defined in '<project>' : overriding.
# [ParamRegistry] Param copper_recycled_share_IN was already defined in '<project>' : overriding.
# Variable 'copper_recycled_share_IN' was already defined : overidding it with param.
# Warning : param 'copper_recycled_share_OUT' linked to root project instead of a specific DB
# [ParamRegistry] Param copper_recycled_share_OUT was already defined in '<project>' : overriding.
# [ParamRegistry] Param copper_recycled_share_OUT was already defined in '<project>' : overriding.
# Variable 'copper_recycled_share_OUT' was already defined : overidding it with param.
# Warning : param 'mass_tower_steel' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_tower_steel was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_tower_steel was already defined in '<project>' : overriding.
# Variable 'mass_tower_steel' was already defined : overidding it with param.
# Warning : param 'mass_tower_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_tower_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_tower_alu was already defined in '<project>' : overriding.
# Variable 'mass_tower_alu' was already defined : overidding it with param.
# Warning : param 'mass_tower_concrete' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_tower_concrete was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_tower_concrete was already defined in '<project>' : overriding.
# Variable 'mass_tower_concrete' was already defined : overidding it with param.
# Warning : param 'mass_glass_fibre_rotor' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_glass_fibre_rotor was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_glass_fibre_rotor was already defined in '<project>' : overriding.
# Variable 'mass_glass_fibre_rotor' was already defined : overidding it with param.
# Warning : param 'mass_steel_personalised_foundations' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_steel_personalised_foundations was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_steel_personalised_foundations was already defined in '<project>' : overriding.
# Variable 'mass_steel_personalised_foundations' was already defined : overidding it with param.
# Warning : param 'mass_concrete_personalised_foundations' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_concrete_personalised_foundations was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_concrete_personalised_foundations was already defined in '<project>' : overriding.
# Variable 'mass_concrete_personalised_foundations' was already defined : overidding it with param.
# Warning : param 'mass_gravel_personalised_foundations' linked to root project instead of a specific DB
# [ParamRegistry] Param mass_gravel_personalised_foundations was already defined in '<project>' : overriding.
# [ParamRegistry] Param mass_gravel_personalised_foundations was already defined in '<project>' : overriding.
# Variable 'mass_gravel_personalised_foundations' was already defined : overidding it with param.
# Warning : param 'd_onshoresite_land' linked to root project instead of a specific DB
# [ParamRegistry] Param d_onshoresite_land was already defined in '<project>' : overriding.
# [ParamRegistry] Param d_onshoresite_land was already defined in '<project>' : overriding.
# Variable 'd_onshoresite_land' was already defined : overidding it with param.
# Warning : param 'd_shore' linked to root project instead of a specific DB
# [ParamRegistry] Param d_shore was already defined in '<project>' : overriding.
# [ParamRegistry] Param d_shore was already defined in '<project>' : overriding.
# Variable 'd_shore' was already defined : overidding it with param.
# Warning : param 'd_riprap' linked to root project instead of a specific DB
# [ParamRegistry] Param d_riprap was already defined in '<project>' : overriding.
# [ParamRegistry] Param d_riprap was already defined in '<project>' : overriding.
# Variable 'd_riprap' was already defined : overidding it with param.
# Warning : param 'd_offshoresite_eol' linked to root project instead of a specific DB
# [ParamRegistry] Param d_offshoresite_eol was already defined in '<project>' : overriding.
# [ParamRegistry] Param d_offshoresite_eol was already defined in '<project>' : overriding.
# Variable 'd_offshoresite_eol' was already defined : overidding it with param.
# Warning : param 'emission_ratio_anode' linked to root project instead of a specific DB
# [ParamRegistry] Param emission_ratio_anode was already defined in '<project>' : overriding.
# [ParamRegistry] Param emission_ratio_anode was already defined in '<project>' : overriding.
# Variable 'emission_ratio_anode' was already defined : overidding it with param.
# Warning : param 'hub_height' linked to root project instead of a specific DB
# [ParamRegistry] Param hub_height was already defined in '<project>' : overriding.
# [ParamRegistry] Param hub_height was already defined in '<project>' : overriding.
# Variable 'hub_height' was already defined : overidding it with param.
# Warning : param 'rotor_diameter' linked to root project instead of a specific DB
# [ParamRegistry] Param rotor_diameter was already defined in '<project>' : overriding.
# [ParamRegistry] Param rotor_diameter was already defined in '<project>' : overriding.
# Variable 'rotor_diameter' was already defined : overidding it with param.
# Warning : param 'steel_ratio_tower' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_ratio_tower was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_ratio_tower was already defined in '<project>' : overriding.
# Variable 'steel_ratio_tower' was already defined : overidding it with param.
# Warning : param 'aluminium_ratio_tower' linked to root project instead of a specific DB
# [ParamRegistry] Param aluminium_ratio_tower was already defined in '<project>' : overriding.
# [ParamRegistry] Param aluminium_ratio_tower was already defined in '<project>' : overriding.
# Variable 'aluminium_ratio_tower' was already defined : overidding it with param.
# Warning : param 'concrete_ratio_tower' linked to root project instead of a specific DB
# [ParamRegistry] Param concrete_ratio_tower was already defined in '<project>' : overriding.
# [ParamRegistry] Param concrete_ratio_tower was already defined in '<project>' : overriding.
# Variable 'concrete_ratio_tower' was already defined : overidding it with param.
# Warning : param 'water_depth' linked to root project instead of a specific DB
# [ParamRegistry] Param water_depth was already defined in '<project>' : overriding.
# [ParamRegistry] Param water_depth was already defined in '<project>' : overriding.
# Variable 'water_depth' was already defined : overidding it with param.
# Warning : param 'copper_ratio_intcable' linked to root project instead of a specific DB
# [ParamRegistry] Param copper_ratio_intcable was already defined in '<project>' : overriding.
# [ParamRegistry] Param copper_ratio_intcable was already defined in '<project>' : overriding.
# Variable 'copper_ratio_intcable' was already defined : overidding it with param.
# Warning : param 'lead_ratio_intcable' linked to root project instead of a specific DB
# [ParamRegistry] Param lead_ratio_intcable was already defined in '<project>' : overriding.
# [ParamRegistry] Param lead_ratio_intcable was already defined in '<project>' : overriding.
# Variable 'lead_ratio_intcable' was already defined : overidding it with param.
# Warning : param 'steel_ratio_intcable' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_ratio_intcable was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_ratio_intcable was already defined in '<project>' : overriding.
# Variable 'steel_ratio_intcable' was already defined : overidding it with param.
# Warning : param 'HDPE_ratio_intcable' linked to root project instead of a specific DB
# [ParamRegistry] Param HDPE_ratio_intcable was already defined in '<project>' : overriding.
# [ParamRegistry] Param HDPE_ratio_intcable was already defined in '<project>' : overriding.
# Variable 'HDPE_ratio_intcable' was already defined : overidding it with param.
# Warning : param 'PP_ratio_intcable' linked to root project instead of a specific DB
# [ParamRegistry] Param PP_ratio_intcable was already defined in '<project>' : overriding.
# [ParamRegistry] Param PP_ratio_intcable was already defined in '<project>' : overriding.
# Variable 'PP_ratio_intcable' was already defined : overidding it with param.
# Warning : param 'alu_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param alu_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param alu_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'alu_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'lead_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param lead_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param lead_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'lead_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'steel_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'steel_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'HDPE_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param HDPE_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param HDPE_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'HDPE_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'PP_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param PP_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param PP_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'PP_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'glass_ratio_expcable_alu' linked to root project instead of a specific DB
# [ParamRegistry] Param glass_ratio_expcable_alu was already defined in '<project>' : overriding.
# [ParamRegistry] Param glass_ratio_expcable_alu was already defined in '<project>' : overriding.
# Variable 'glass_ratio_expcable_alu' was already defined : overidding it with param.
# Warning : param 'copper_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param copper_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param copper_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'copper_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'lead_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param lead_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param lead_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'lead_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'steel_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param steel_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param steel_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'steel_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'HDPE_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param HDPE_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param HDPE_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'HDPE_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'PP_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param PP_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param PP_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'PP_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'glass_ratio_expcable_cop' linked to root project instead of a specific DB
# [ParamRegistry] Param glass_ratio_expcable_cop was already defined in '<project>' : overriding.
# [ParamRegistry] Param glass_ratio_expcable_cop was already defined in '<project>' : overriding.
# Variable 'glass_ratio_expcable_cop' was already defined : overidding it with param.
# Warning : param 'length_expcables_tot' linked to root project instead of a specific DB
# [ParamRegistry] Param length_expcables_tot was already defined in '<project>' : overriding.
# [ParamRegistry] Param length_expcables_tot was already defined in '<project>' : overriding.
# Variable 'length_expcables_tot' was already defined : overidding it with param.
# Warning : param 'length_expcables_copper' linked to root project instead of a specific DB
# [ParamRegistry] Param length_expcables_copper was already defined in '<project>' : overriding.
# [ParamRegistry] Param length_expcables_copper was already defined in '<project>' : overriding.
# Variable 'length_expcables_copper' was already defined : overidding it with param.
# Warning : param 'foundations' linked to root project instead of a specific DB
# [ParamRegistry] Param foundations was already defined in '<project>' : overriding.
# [ParamRegistry] Param foundations was already defined in '<project>' : overriding.
# Variable 'foundations' was already defined : overidding it with param.
# Warning : param 'preassembly' linked to root project instead of a specific DB
# [ParamRegistry] Param preassembly was already defined in '<project>' : overriding.
# [ParamRegistry] Param preassembly was already defined in '<project>' : overriding.
# Variable 'preassembly' was already defined : overidding it with param.

# %%
USER_DB="lif-owi"

# %%
LCIA_method = 'EF v3.0'
#climate_tot = (LCIA_method,'climate change no LT','global warming potential (GWP100) no LT')
climate_tot = (LCIA_method,'climate change','global warming potential (GWP100)')

#climate_bio = (LCIA_method,'climate change: biogenic no LT','global warming potential (GWP100) no LT')
climate_bio = (LCIA_method,'climate change: biogenic','global warming potential (GWP100)')

#climate_foss = (LCIA_method,'climate change: fossil no LT','global warming potential (GWP100) no LT')
climate_foss = (LCIA_method,'climate change: fossil','global warming potential (GWP100)')

#climate_land = (LCIA_method,'climate change: land use and land use change no LT','global warming potential (GWP100) no LT')
climate_land = (LCIA_method,'climate change: land use and land use change','global warming potential (GWP100)')

#ecosystem_quality_ecotox= (LCIA_method,'ecotoxicity: freshwater no LT','comparative toxic unit for ecosystems (CTUe)  no LT')
ecosystem_quality_ecotox= (LCIA_method,'ecotoxicity: freshwater','comparative toxic unit for ecosystems (CTUe) ')

#ecosystem_quality_acid = (LCIA_method,'acidification no LT','accumulated exceedance (ae) no LT')
ecosystem_quality_acid = (LCIA_method,'acidification','accumulated exceedance (ae)')

#ecosystem_quality_fresh_eut = (LCIA_method,'eutrophication: freshwater no LT','fraction of nutrients reaching freshwater end compartment (P) no LT')
ecosystem_quality_fresh_eut = (LCIA_method,'eutrophication: freshwater','fraction of nutrients reaching freshwater end compartment (P)')

#ecosystem_quality_mar_eut = (LCIA_method,'eutrophication: marine no LT','fraction of nutrients reaching marine end compartment (N) no LT'),
ecosystem_quality_mar_eut = (LCIA_method,'eutrophication: marine','fraction of nutrients reaching marine end compartment (N)')

#ecosystem_quality_ter_eut=(LCIA_method,'eutrophication: terrestrial no LT','accumulated exceedance (AE)  no LT')
ecosystem_quality_ter_eut=(LCIA_method,'eutrophication: terrestrial','accumulated exceedance (AE) ')

#human_health_io= (LCIA_method,'ionising radiation: human health no LT','human exposure efficiency relative to u235 no LT')
human_health_io= (LCIA_method,'ionising radiation: human health','human exposure efficiency relative to u235')

#human_health_oz= (LCIA_method,'ozone depletion no LT','ozone depletion potential (ODP)  no LT')
human_health_oz= (LCIA_method,'ozone depletion','ozone depletion potential (ODP) ')

#human_health_pht= (LCIA_method, 'photochemical ozone formation: human health no LT','tropospheric ozone concentration increase no LT')
human_health_pht= (LCIA_method, 'photochemical ozone formation: human health','tropospheric ozone concentration increase')

#human_health_res= (LCIA_method,'particulate matter formation no LT','impact on human health no LT')
human_health_res= (LCIA_method,'particulate matter formation','impact on human health')

#human_health_noncar= (LCIA_method,'human toxicity: non-carcinogenic no LT','comparative toxic unit for human (CTUh)  no LT')
human_health_noncar= (LCIA_method,'human toxicity: non-carcinogenic','comparative toxic unit for human (CTUh) ')

#human_health_car= (LCIA_method,'human toxicity: carcinogenic no LT','comparative toxic unit for human (CTUh)  no LT')
human_health_car= (LCIA_method,'human toxicity: carcinogenic','comparative toxic unit for human (CTUh) ')

#resources_foss =(LCIA_method,  'energy resources: non-renewable no LT',  'abiotic depletion potential (ADP): fossil fuels no LT')
resources_foss =(LCIA_method,  'energy resources: non-renewable',  'abiotic depletion potential (ADP): fossil fuels')

#resources_land = (LCIA_method, 'land use no LT', 'soil quality index no LT')
resources_land = (LCIA_method, 'land use', 'soil quality index')

#resources_min_met =(LCIA_method,'material resources: metals/minerals no LT','abiotic depletion potential (ADP): elements (ultimate reserves) no LT')
resources_min_met =(LCIA_method,'material resources: metals/minerals','abiotic depletion potential (ADP): elements (ultimate reserves)')

# resources_water = (LCIA_method,  'water use no LT',  'user deprivation potential (deprivation-weighted water consumption) no LT')
resources_water = (LCIA_method,  'water use',  'user deprivation potential (deprivation-weighted water consumption)')

impacts_EF_3_0 = [climate_tot, climate_bio, climate_foss, climate_land, ecosystem_quality_ecotox,ecosystem_quality_acid,
                  ecosystem_quality_fresh_eut,
                  ecosystem_quality_mar_eut,
                  ecosystem_quality_ter_eut, human_health_io,
                  human_health_oz, human_health_pht, human_health_res, human_health_noncar, human_health_car, resources_foss,
                  resources_land, resources_min_met, resources_water]

#We define a list of 1 impact (climate change impact) to do verification & comparisation
impacts_EF_CO2 = [climate_tot]

# %%
models = {key:agb.findActivity(code=code, db_name=USER_DB) for key, code in MODELS.items()}

# %%
res = export_lca(
    system=models["complete_system"],
    functional_units={
        "system":1,
        "per_turbine":1/n_turbines},
    methods_dict=impacts_dict,
    axis="system_1")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 res = export_lca(
#       2     system=models["complete_system"],
#       3     functional_units={
#       4         "system":1,
#       5         "per_turbine":1/n_turbines},
#       6     methods_dict=impacts_dict,
#       7     axis="system_1")
#
# File ~/lifowi/lca_algebraic/export.py:39, in export_lca(system, functional_units, methods_dict, axis, num_digits)
#      36 all_params = {param.name: Param.from_ParamDef(param) for param in _param_registry().all() if param.name in param_names}
#      38 # Dict of lambdas
# ---> 39 impacts = {method : Lambda(lambd.expr, all_params) for method, lambd in zip(methods_dict.keys(), lambdas)}
#      40 functional_units = {key: Lambda(expr, all_params) for key, expr in functional_units.item()}
#      42 return Model(
#      43     params=all_params,
#      44     functional_units=functional_units,
#      45     impacts=impacts)
#
# File ~/lifowi/lca_algebraic/export.py:39, in <dictcomp>(.0)
#      36 all_params = {param.name: Param.from_ParamDef(param) for param in _param_registry().all() if param.name in param_names}
#      38 # Dict of lambdas
# ---> 39 impacts = {method : Lambda(lambd.expr, all_params) for method, lambd in zip(methods_dict.keys(), lambdas)}
#      40 functional_units = {key: Lambda(expr, all_params) for key, expr in functional_units.item()}
#      42 return Model(
#      43     params=all_params,
#      44     functional_units=functional_units,
#      45     impacts=impacts)
#
# File ~/lifowi/lca_algebraic/export.py:65, in Lambda.__init__(self, expr, all_params)
#      63 def __init__(self, expr, all_params):
# ---> 65     expanded_params = list(str(symbol) for symbol in expr.free_symbol())
#      67     self.params = unexpand_param_names(all_params, expanded_params)
#      68     if isinstance(expr, dict) :
#
# AttributeError: 'dict' object has no attribute 'free_symbol'

# %%
res
# Out:
# [{inter-array cables: n_turbines*turbine_MW*(1.55e-9*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.82e-10*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(3.99e-7*life_time + 1.29e-5)*(n_turbines - 1) + fixed_foundations*(-1.28e-7*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 1.04e-6*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 7.63e-7*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcabl ...
#  {inter-array cables: n_turbines*turbine_MW*(6.96e-5*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.19e-6*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(0.0664*life_time + 2.15)*(n_turbines - 1) + fixed_foundations*(-0.012*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.77*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.7*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_rati ...
#  {inter-array cables: n_turbines*turbine_MW*(1.68e-8*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.97e-9*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(1.35e-5*life_time + 0.000459)*(n_turbines - 1) + fixed_foundations*(-4.48e-6*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 4.35e-5*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.76e-5*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcabl ...
#  {inter-array cables: n_turbines*turbine_MW*(3.62e-10*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 4.26e-11*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(1.03e-7*life_time + 3.35e-6)*(n_turbines - 1) + fixed_foundations*(-5.07e-8*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 1.43e-6*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 1.02e-6*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcab ...
#  {inter-array cables: n_turbines*turbine_MW*(3.83e-9*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 4.51e-10*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(1.89e-6*life_time + 6.67e-5)*(n_turbines - 1) + fixed_foundations*(-2.92e-5*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.85e-5*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 1.13e-5*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcabl ...
#  {inter-array cables: n_turbines*turbine_MW*(4.16e-8*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 4.9e-9*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(2.05e-5*life_time + 0.000723)*(n_turbines - 1) + fixed_foundations*(-1.85e-5*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.000225*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.000129*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcab ...
#  {inter-array cables: n_turbines*turbine_MW*(4.45e-7*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 5.23e-8*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(0.000608*life_time + 0.0197)*(n_turbines - 1) + fixed_foundations*(-8.86e-5*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.000117*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.000223*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcab ...
#  {inter-array cables: n_turbines*turbine_MW*(1.31e-12*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.54e-13*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(2.17e-9*life_time + 7.03e-8)*(n_turbines - 1) + fixed_foundations*(-1.88e-10*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 4.3e-10*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 3.97e-10*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intc ...
#  {inter-array cables: n_turbines*turbine_MW*(1.64e-8*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.92e-9*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(8.52e-6*life_time + 0.000291)*(n_turbines - 1) + fixed_foundations*(-7.23e-6*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 5.49e-5*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 3.47e-5*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcabl ...
#  {inter-array cables: n_turbines*turbine_MW*(6.18e-13*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 7.28e-14*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(5.41e-11*life_time + 1.92e-9)*(n_turbines - 1) + fixed_foundations*(-9.9e-11*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.39e-10*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.78e-10*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_int ...
#  {inter-array cables: n_turbines*turbine_MW*(2.02e-15*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 2.38e-16*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(5.51e-13*life_time + 1.82e-11)*(n_turbines - 1) + fixed_foundations*(-4.29e-13*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 3.76e-11*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.27e-11*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_i ...
#  {inter-array cables: n_turbines*turbine_MW*(8.52e-5*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.0e-5*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(0.131*life_time + 4.25)*(n_turbines - 1) + fixed_foundations*(-0.0136*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.0199*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.0309*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ ...
#  {inter-array cables: n_turbines*turbine_MW*(9.94e-5*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.17e-5*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(0.0162*life_time + 0.527)*(n_turbines - 1) + fixed_foundations*(-0.0359*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.00698*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.0446*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + st ...
#  {inter-array cables: n_turbines*turbine_MW*(1.34e-11*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 1.58e-12*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(1.35e-9*life_time + 4.37e-8)*(n_turbines - 1) + fixed_foundations*(-1.81e-9*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 1.86e-8*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 2.35e-8*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcab ...
#  {inter-array cables: n_turbines*turbine_MW*(3.87e-7*pi*d_onshoresite_land*fixed_foundations*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 4.55e-8*pi*d_onshoresite_land*(1 - fixed_foundations)*(n_turbines - 1)*(8.5*rotor_diameter + 4*water_depth)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW) + 8.5*fixed_foundations*rotor_diameter*(0.00015*life_time + 0.00486)*(n_turbines - 1) + fixed_foundations*(-0.000116*pi*HDPE_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.002*pi*PP_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 11342*lead_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 7850*steel_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable))/(n_turbines*turbine_MW*(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable)) + 0.00177*pi*copper_ratio_intcable*rotor_diameter*(n_turbines - 1)*(970*HDPE_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 946*PP_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable + steel_ratio_intcable) + 8960*copper_ratio_intcable/(HDPE_ratio_intcable + PP_ratio_intcable + copper_ratio_intcable + lead_ratio_intcable  ...

# %%
res[1].expr
# Out:
# -23.2906013937661*alu_recycled_share_IN - 82.8236574868863*steel_recycled_share_IN + 515.850388023041 + 217022.0*(0.00261667048429949 - 0.00261667048429949*steel_recycled_share_IN)/turbine_MW + 3978.0*(0.0207249739665509 - 0.0207249739665509*alu_recycled_share_IN)/turbine_MW + 185.420897101252/turbine_MW

# %%
lambdas[0].params
# Out:
# {'HDPE_ratio_expcable_alu',
#  'HDPE_ratio_expcable_cop',
#  'HDPE_ratio_intcable',
#  'PP_ratio_expcable_alu',
#  'PP_ratio_expcable_cop',
#  'PP_ratio_intcable',
#  'alu_incineration_share',
#  'alu_landfill_share',
#  'alu_ratio_expcable_alu',
#  'alu_recycled_share_IN',
#  'alu_recycled_share_OUT',
#  'concrete_recycled_share_OUT',
#  'copper_ratio_expcable_cop',
#  'copper_ratio_intcable',
#  'd_offshoresite_eol',
#  'd_onshoresite_land',
#  'd_riprap',
#  'd_shore',
#  'emission_ratio_anode',
#  'fixed_foundations',
#  'foundations',
#  'glass_ratio_expcable_alu',
#  'glass_ratio_expcable_cop',
#  'lead_ratio_expcable_alu',
#  'lead_ratio_expcable_cop',
#  'lead_ratio_intcable',
#  'length_expcables_copper',
#  'length_expcables_tot',
#  'life_time',
#  'n_turbines',
#  'preassembly',
#  'rotor_diameter',
#  'steel_ratio_expcable_alu',
#  'steel_ratio_expcable_cop',
#  'steel_ratio_intcable',
#  'steel_recycled_share_IN',
#  'steel_recycled_share_OUT',
#  'turbine_MW',
#  'water_depth'}

# %%
set().union(*[list(lambd.params) for lambd in lambdas])
# Out:
# {'HDPE_ratio_expcable_alu',
#  'HDPE_ratio_expcable_cop',
#  'HDPE_ratio_intcable',
#  'PP_ratio_expcable_alu',
#  'PP_ratio_expcable_cop',
#  'PP_ratio_intcable',
#  'alu_incineration_share',
#  'alu_landfill_share',
#  'alu_ratio_expcable_alu',
#  'alu_recycled_share_IN',
#  'alu_recycled_share_OUT',
#  'concrete_recycled_share_OUT',
#  'copper_ratio_expcable_cop',
#  'copper_ratio_intcable',
#  'd_offshoresite_eol',
#  'd_onshoresite_land',
#  'd_riprap',
#  'd_shore',
#  'emission_ratio_anode',
#  'fixed_foundations',
#  'foundations',
#  'glass_ratio_expcable_alu',
#  'glass_ratio_expcable_cop',
#  'lead_ratio_expcable_alu',
#  'lead_ratio_expcable_cop',
#  'lead_ratio_intcable',
#  'length_expcables_copper',
#  'length_expcables_tot',
#  'life_time',
#  'n_turbines',
#  'preassembly',
#  'rotor_diameter',
#  'steel_ratio_expcable_alu',
#  'steel_ratio_expcable_cop',
#  'steel_ratio_intcable',
#  'steel_recycled_share_IN',
#  'steel_recycled_share_OUT',
#  'turbine_MW',
#  'water_depth'}

# %%
param_names = list(set().union(*[list(lambd.params) for lambd in lambdas]))
all_params = {param.name: Param.from_ParamDef(param) for param in _param_registry().all() if param.name in param_names}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 param_names = list(set().union(*[list(lambd.params) for lambd in lambdas]))
# ----> 2 all_params = {param.name: Param.from_ParamDef(param) for param in _param_registry().all() if param.name in param_names}
#
# Cell In[19], line 2, in <dictcomp>(.0)
#       1 param_names = list(set().union(*[list(lambd.params) for lambd in lambdas]))
# ----> 2 all_params = {param.name: Param.from_ParamDef(param) for param in _param_registry().all() if param.name in param_names}
#
# NameError: name 'Param' is not defined
